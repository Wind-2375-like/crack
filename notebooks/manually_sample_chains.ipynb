# %%
import requests
import numpy as np
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
from typing import Optional, List, Tuple, Dict, Any
import time # Import time for potential delays/retries
import calendar, datetime
from datetime import datetime, timezone

# --- Wikidata Interaction Setup ---
from wikibaseintegrator import WikibaseIntegrator, wbi_login
from wikibaseintegrator.datatypes import String
from wikibaseintegrator.wbi_config import config as wbi_config

# Configure User Agent and Login (using OAuth2 as in the original code)
# IMPORTANT: Replace placeholders if necessary, ensure credentials are secure
wbi_config['USER_AGENT'] = 'MyWikibaseBot/1.0 (https://www.wikidata.org/wiki/User:Wind2375like)' # Please update URL if applicable
try:
    # Ensure your consumer token/secret are correctly set up for OAuth2
    login = wbi_login.OAuth2(consumer_token='8af6056534b5a48d227d6f36c1d44e7f', consumer_secret='f4efe05f57d81a14b4f646f3228f214773e9299a')
    wbi = WikibaseIntegrator(login=login)
    print("WikibaseIntegrator initialized with OAuth2 login.")
except Exception as e:
    print(f"Warning: Failed to initialize WikibaseIntegrator with OAuth2 login: {e}")
    print("Falling back to anonymous WikibaseIntegrator.")
    # Fallback to anonymous access if OAuth fails or is not needed for reads
    wbi = WikibaseIntegrator()
# Out:
# WikibaseIntegrator initialized with OAuth2 login.

# %%
# --- Configuration ---
MAX_DEPTH = 5 # Default max depth for chain building
ALLOWED_PROPS = {
    "P39", # position held
    "P36", "P35", "P6", "P20", "P26", "P140", "P1412",
    "P19", "P69", "P40", "P27", "P175", "P108", "P112", "P50",
    "P170", "P407", "P37", "P740", "P495", "P106", "P136", "P364",
    "P937", "P800", "P641", "P413", "P286", "P159", "P178", "P488",
    "P169", "P449", "P176", "P1037", "P1308"
    # Add more properties relevant to potential changes if needed
}
UA = "MyWikibaseBot/1.0 (https://www.wikidata.org/wiki/User:Wind2375like)"
# THRESHOLD_LINK_COUNT = 1 # Original threshold, not directly used in build_chain logic but kept for context

# %%
import requests
import numpy as np
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
from datetime import datetime, timezone
from wikibaseintegrator import wbi_helpers, WikibaseIntegrator
from typing import List, Tuple, Set

def get_wikidata_label(entity_id: str, lang: str = "en") -> str:
    """
    Fetches the label for a Wikidata entity (e.g. 'Q42' or 'P31') in the specified language.

    :param entity_id: The Wikidata ID (e.g. 'Q42' for Douglas Adams, 'P31' for instance of).
    :param lang:       The language code for the label (default 'en').
    :return:           The label string, or an empty string if not found.
    """
    url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbgetentities",
        "ids": entity_id,
        "props": "labels",
        "languages": lang,
        "format": "json"
    }
    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json()

    # Navigate the JSON to extract the label
    entities = data.get("entities", {})
    entity = entities.get(entity_id, {})
    labels = entity.get("labels", {})
    label_info = labels.get(lang, {})

    return label_info.get("value", "")

def recent_items_since_rc(
    since_iso: str,
    limit: int = 50,
    namespaces: str = "0"              # 0 = items only
) -> List[str]:
    """
    Return up to `limit` Q-ids whose *item* was edited after `since_iso` (UTC),
    using only the MediaWiki RecentChanges feed (no WDQS).
    """
    data = {
        "action": "query",
        "list":   "recentchanges",
        "rcnamespace": namespaces,
        "rcstart": since_iso,          # ISO 8601, newest first → use as lower bound
        "rcdir":   "newer",
        "rctype":  "edit|new",
        "rclimit": limit,
        "rcprop":  "title",
        "format":  "json"
    }
    rc_json = wbi_helpers.mediawiki_api_call_helper(
        data=data,
        allow_anonymous=True,
        user_agent=UA
    )
    return [
        rc["title"] for rc in rc_json["query"]["recentchanges"]
        if rc["title"].startswith("Q")
    ][:limit]

def recent_triples_since_rc(
    since_iso: str,
    allowed_props: Set[str],
    limit: int = 50
) -> List[Tuple[str, str, str]]:
    """
    Return up to `limit` (s, p, o) triples where the statement lives on an
    item edited after `since_iso` and `p` is in `allowed_props`.
    Works only with the Wikidata API — no SPARQL, no WDQS timeouts.
    """
    triples: List[Tuple[str, str, str]] = []
    for qid in recent_items_since_rc(since_iso, limit * 10):   # oversample a bit
        claims = wbi.item.get(entity_id=qid).get_json().get("claims", {})
        for prop, claim_list in claims.items():
            if prop not in allowed_props or len(claim_list) != 1:
                continue
            val = (claim_list[0]
                   .get("mainsnak", {})
                   .get("datavalue", {})
                   .get("value", {}))
            if isinstance(val, dict) and "id" in val:
                if get_wikidata_label(qid) == "" or get_wikidata_label(val["id"]) == "":
                    continue
                triples.append((qid, prop, val["id"]))
                if len(triples) >= limit:
                    return triples
    return triples

def get_random_qid() -> str:
    """
    Uses the MediaWiki API to pick a random main-namespace page
    and returns its Q‑ID (always starts with 'Q'). Loops until
    a valid Q‑ID is found.
    """
    session = requests.Session()
    URL = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'query',
        'list': 'random',
        'rnnamespace': 0,
        'rnlimit': 1,
        'format': 'json'
    }

    while True:
        resp = session.get(URL, params=params).json()
        title = resp['query']['random'][0]['title']
        # Only accept titles that look like valid Q‑IDs
        if title.startswith("Q") and title[1:].isdigit():
            return title

def get_link_counts(qid):
    """
    Use SPARQL to get the number of links for a given QID
    """

    endpoint_url = "https://query.wikidata.org/sparql"

    query = f"""SELECT ?item ?count WHERE {{
        VALUES ?item {{ wd:{qid} }} .
        # ?item wikibase:sitelinks ?count .
    }}"""

    user_agent = "getLinkCounts (https://github.com/Wind-2375-like)"
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    if len(results["results"]["bindings"]) == 0:
        print(f"No results found for {qid}")
        return 0
    count = results["results"]["bindings"][0]["count"]["value"]
    count = int(count)
    return count

# %%
def _claim_active_at(claim: dict, when: datetime) -> bool:
    """
    Return True iff the claim is valid at the given instant, according to
    its P580 (start time) / P582 (end time) qualifiers.  If neither qualifier
    is present we treat the claim as always-valid.
    """
    qs = claim.get("qualifiers", {})
    fmt = "%Y-%m-%dT%H:%M:%SZ"

    # start time
    if "P580" in qs:
        start_raw = qs["P580"][0]["datavalue"]["value"]["time"]   # "+2021-01-20T00:00:00Z"
        try:
            start = datetime.strptime(start_raw[1:], fmt).replace(tzinfo=timezone.utc)
        except ValueError:
            # Handle the case where the date is not in the expected format
            return False
        if when < start:
            return False

    # end time
    if "P582" in qs:
        end_raw = qs["P582"][0]["datavalue"]["value"]["time"]
        try:
            end = datetime.strptime(end_raw[1:], fmt).replace(tzinfo=timezone.utc)
        except ValueError:
            # Handle the case where the date is not in the expected format
            return False
        if when >= end:
            return False     # ended *before* or *at* this instant

    return True

def _has(claims: dict, prop: str, obj: str, when: datetime) -> bool:
    for claim in claims.get(prop, []):
        dv = claim.get("mainsnak", {}).get("datavalue", {})
        val = dv.get("value", {})
        if isinstance(val, dict) and val.get("id") == obj:
            if _claim_active_at(claim, when):
                return True
    return False

def _to_dt(month_str: str, end: bool) -> datetime:
    """'YYYY-MM' → last (or first) second of that month, in UTC."""
    y, m = map(int, month_str.split('-'))
    d = calendar.monthrange(y, m)[1] if end else 1
    hms = "23:59:59" if end else "00:00:00"
    return datetime.strptime(f"{y:04d}-{m:02d}-{d:02d} {hms}", "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

def is_updated_triple(triple, before_time, after_time):
    subj, prop, obj = triple
    before_dt = _to_dt(before_time, end=True)
    after_dt  = _to_dt(after_time,  end=True)

    claims_now = wbi.item.get(entity_id=subj).get_json()["claims"]

    was_true = _has(claims_now, prop, obj, before_dt)
    is_true  = True

    return was_true != is_true

def build_chain(start_qid: str, max_depth: int = 5):
    """
    Returns a list of (e_i, p_i, e_{i+1}) up to max_depth,
    never revisiting the same entity.
    """
    chain = []
    visited = {start_qid}
    current = start_qid

    for i in range(max_depth):
        # 1) Fetch the item
        item = wbi.item.get(entity_id=current)
        claims = item.get_json().get('claims', {})

        # 2) Scan for the first outgoing Item link that doesn't revisit
        found = False
        for prop, claim_list in claims.items():
            # Skip if this property is not in the allowed set
            if prop not in ALLOWED_PROPS:
                continue

            # Skip if not a single claim
            if len(claim_list) != 1:
                continue
            
            claim = claim_list[0]
            dv = claim.get('mainsnak', {}).get('datavalue', {})
            val = dv.get('value', {})

            # check that it’s an item link
            if isinstance(val, dict) and 'id' in val:
                nxt = val['id']
                if nxt in visited:
                    # would form a cycle
                    continue
                
                if get_wikidata_label(current) == "" or get_wikidata_label(nxt) == "" or get_wikidata_label(prop) == "":
                    # skip if any label is empty
                    continue
                
                # if i == 0 and not is_updated_triple(triple=(current, prop, nxt), before_time="2023-12", after_time="2025-04"):
                #     # skip if the triple is not updated
                #     continue

                # record the triple and advance the chain
                chain.append({
                    "triple": (current, prop, nxt),
                    "triple_label": (get_wikidata_label(current), get_wikidata_label(prop), get_wikidata_label(nxt)),
                })
                visited.add(nxt)
                current = nxt
                found = True
                break

        if not found:
            # no further step possible
            break

    return chain

def sample_chain_exact(depth: int) -> List[Tuple[str, str, str]]:
    """
    Sample a chain with exactly length==depth such that:
    1. No entity is revisited (i.e. no cycles)
    2. The first triple is updated between 2023-12 and 2025-04
    3. The properties are in the allowed set
    4. There is only one claim for each property
    5. The labels for the entities and properties are not empty
    """
    tries = 0
    while True:
        tries += 1
        # start = recent_triples_since_rc("2023-12-31T00:00:00Z", allowed_props=ALLOWED_PROPS, limit=1)
        start = get_random_qid()
        if not start:
            continue
        # chain = build_chain(start[0][0], max_depth=depth)
        chain = build_chain(start, max_depth=depth)
        if len(chain) == depth:
            # print(f"Found after {tries} tries, start={start}")
            return chain

# print(sample_chain_exact(depth=5))

# %%
from tqdm import tqdm
chains = []
for i in tqdm(range(100)):
    try:
        chain = sample_chain_exact(depth=5)
        chains.append(chain)
        # print(f"Chain {i+1}: {chain}")
    except Exception as e:
        print(f"Error on iteration {i+1}: {e}")
        time.sleep(1)  # Sleep to avoid hitting API limits or causing too many errors
        continue
# Out:
#   2%|▏         | 2/100 [03:10<2:43:18, 99.99s/it]
# Error on iteration 3: ('Connection aborted.', TimeoutError(60, 'Operation timed out'))
#   3%|▎         | 3/100 [10:23<6:47:29, 252.06s/it]Connection error: ('Connection aborted.', OSError(49, "Can't assign requested address")). Sleeping for 60 seconds.
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# OSError: [Errno 49] Can't assign requested address
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/util/retry.py", line 474, in increment
#     raise reraise(type(error), error, _stacktrace)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/util/util.py", line 38, in reraise
#     raise value.with_traceback(tb)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/urllib3/connection.py", line 464, in getresponse
#     httplib_response = super().getresponse()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# urllib3.exceptions.ProtocolError: ('Connection aborted.', OSError(49, "Can't assign requested address"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/wikibaseintegrator/wbi_helpers.py", line 78, in mediawiki_api_call
#     response = session.request(method=method, url=mediawiki_api_url, **kwargs)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/opt/miniconda3/envs/hallucination/lib/python3.9/site-packages/requests/adapters.py", line 682, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', OSError(49, "Can't assign requested address"))
#  13%|█▎        | 13/100 [27:17<2:06:48, 87.45s/it] Service unavailable (HTTP Code 502). Sleeping for 60 seconds.
# 100%|██████████| 100/100 [3:29:14<00:00, 125.55s/it]

# %%
# Save the chains to a file
import pickle
with open("chains.pkl", "wb") as f:
    pickle.dump(chains, f)

# %% [markdown]
# - [give up too long] Start from a changed triple from 2023-12 to 2025-04 (now) (20min)
# - [x] Generate 100 chains (immediately)
# - [x] Summarize the code (10min)
# - [] Use the templates to generate probe questions and whole questions (30min)
# - [] Test script for Llama 3.2 on questions (10min)
# - [] Test script for Llama 3.2 on triples of failed questions (10min)
# - [] Script for Llama 3.2 to inject new knowledge (10min)

# %%
# 1. The final format for each chain is a dictionary with the following keys:
#    - "triples": a list of dictionaries, each containing:
#       - "triple": a tuple of (subject, property, object) IDs
#       - "triple_label": a tuple of (subject label, property label, object label)
#    - "probe_questions": a list of dictionaries with the same length as triples, each containing:
#        - "question": the question-like probe, e.g., Which continent is [S] located in? (P30)
#        - "cloze": the cloze-style probe, e.g., [S] is located in the continent of ___ (P30)
#        - "answer": the answer to the probe, e.g., Asia (Q48)
#    - "multihop_questions": list of strings (3 paraphrased multi-hop questions asking the tail entity from the head entity)
#    - "multihop_answers": list of strings (aliases of the tail entity)
# Out:
# [[{'triple': ('Q102400597', 'P69', 'Q1190812'),
#    'triple_label': ('Xi Ronald Chen',
#     'educated at',
#     'University of New Mexico')},
#   {'triple': ('Q1190812', 'P159', 'Q34804'),
#    'triple_label': ('University of New Mexico',
#     'headquarters location',
#     'Albuquerque')},
#   {'triple': ('Q34804', 'P6', 'Q7807370'),
#    'triple_label': ('Albuquerque', 'head of government', 'Timothy M. Keller')},
#   {'triple': ('Q7807370', 'P27', 'Q30'),
#    'triple_label': ('Timothy M. Keller',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q17328085', 'P170', 'Q175257'),
#    'triple_label': ("Een beer overvalt een houthakker, genaamd 'Strijd op leven en dood'",
#     'creator',
#     'Charles Verlat')},
#   {'triple': ('Q175257', 'P19', 'Q12892'),
#    'triple_label': ('Charles Verlat', 'place of birth', 'Antwerp')},
#   {'triple': ('Q12892', 'P6', 'Q336599'),
#    'triple_label': ('Antwerp', 'head of government', 'Bart De Wever')},
#   {'triple': ('Q336599', 'P19', 'Q688781'),
#    'triple_label': ('Bart De Wever', 'place of birth', 'Mortsel')},
#   {'triple': ('Q688781', 'P36', 'Q31824113'),
#    'triple_label': ('Mortsel', 'capital', 'Mortsel')}],
#  [{'triple': ('Q111426672', 'P108', 'Q503308'),
#    'triple_label': ('Nikki Sereika', 'employer', 'Southwest Airlines')},
#   {'triple': ('Q503308', 'P159', 'Q16557'),
#    'triple_label': ('Southwest Airlines', 'headquarters location', 'Dallas')},
#   {'triple': ('Q16557', 'P6', 'Q5386829'),
#    'triple_label': ('Dallas', 'head of government', 'Eric Johnson')},
#   {'triple': ('Q5386829', 'P27', 'Q30'),
#    'triple_label': ('Eric Johnson',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q5726057', 'P69', 'Q232141'),
#    'triple_label': ('Benjamín Claro Velasco',
#     'educated at',
#     'University of Chile')},
#   {'triple': ('Q232141', 'P112', 'Q439195'),
#    'triple_label': ('University of Chile', 'founded by', 'Andrés Bello')},
#   {'triple': ('Q439195', 'P19', 'Q1533'),
#    'triple_label': ('Andrés Bello', 'place of birth', 'Caracas')},
#   {'triple': ('Q1533', 'P112', 'Q2352507'),
#    'triple_label': ('Caracas', 'founded by', 'Diego de Losada')},
#   {'triple': ('Q2352507', 'P19', 'Q1769047'),
#    'triple_label': ('Diego de Losada',
#     'place of birth',
#     'Rionegro del Puente')}],
#  [{'triple': ('Q102245788', 'P69', 'Q156737'),
#    'triple_label': ('Sönke Blunck', 'educated at', 'University of Kiel')},
#   {'triple': ('Q156737', 'P159', 'Q1707'),
#    'triple_label': ('University of Kiel', 'headquarters location', 'Kiel')},
#   {'triple': ('Q1707', 'P6', 'Q15429738'),
#    'triple_label': ('Kiel', 'head of government', 'Ulf Kämpfer')},
#   {'triple': ('Q15429738', 'P27', 'Q183'),
#    'triple_label': ('Ulf Kämpfer', 'country of citizenship', 'Germany')},
#   {'triple': ('Q183', 'P37', 'Q188'),
#    'triple_label': ('Germany', 'official language', 'German')}],
#  [{'triple': ('Q97741443', 'P106', 'Q937857'),
#    'triple_label': ('Justine Bauduin',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q117245609', 'P40', 'Q27825764'),
#    'triple_label': ('Daniel Delprat', 'child', 'Daniël Delprat')},
#   {'triple': ('Q27825764', 'P106', 'Q1423891'),
#    'triple_label': ('Daniël Delprat', 'occupation', 'Christian minister')},
#   {'triple': ('Q1423891', 'P140', 'Q5043'),
#    'triple_label': ('Christian minister',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')}],
#  [{'triple': ('Q15406665', 'P175', 'Q213670'),
#    'triple_label': ('30-11-80', 'performer', 'Sido')},
#   {'triple': ('Q213670', 'P136', 'Q11401'),
#    'triple_label': ('Sido', 'genre', 'hip-hop')},
#   {'triple': ('Q11401', 'P495', 'Q30'),
#    'triple_label': ('hip-hop', 'country of origin', 'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q62336597', 'P50', 'Q7709525'),
#    'triple_label': ('Surface Chemical Studies on Pyrite in the Presence of Polysaccharide-Based Flotation Depressants',
#     'author',
#     'Thalappil Pradeep')},
#   {'triple': ('Q7709525', 'P108', 'Q622358'),
#    'triple_label': ('Thalappil Pradeep',
#     'employer',
#     'Indian Institutes of Technology')},
#   {'triple': ('Q622358', 'P112', 'Q1047'),
#    'triple_label': ('Indian Institutes of Technology',
#     'founded by',
#     'Jawaharlal Nehru')},
#   {'triple': ('Q1047', 'P40', 'Q1149'),
#    'triple_label': ('Jawaharlal Nehru', 'child', 'Indira Gandhi')},
#   {'triple': ('Q1149', 'P26', 'Q554175'),
#    'triple_label': ('Indira Gandhi', 'spouse', 'Feroze Gandhi')}],
#  [{'triple': ('Q3373652', 'P27', 'Q148'),
#    'triple_label': ('Guo Weicheng',
#     'country of citizenship',
#     "People's Republic of China")},
#   {'triple': ('Q148', 'P36', 'Q956'),
#    'triple_label': ("People's Republic of China", 'capital', 'Beijing')},
#   {'triple': ('Q956', 'P6', 'Q28417331'),
#    'triple_label': ('Beijing', 'head of government', 'Yin Yong')},
#   {'triple': ('Q28417331', 'P69', 'Q16955'),
#    'triple_label': ('Yin Yong', 'educated at', 'Tsinghua University')},
#   {'triple': ('Q16955', 'P488', 'Q19692053'),
#    'triple_label': ('Tsinghua University', 'chairperson', 'Qiu Yong')}],
#  [{'triple': ('Q5661912', 'P106', 'Q937857'),
#    'triple_label': ('Harold Oliver',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q51885166', 'P106', 'Q937857'),
#    'triple_label': ('Adolphe Nicolay',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q18529708', 'P27', 'Q215'),
#    'triple_label': ('Ivan Starina', 'country of citizenship', 'Slovenia')},
#   {'triple': ('Q215', 'P36', 'Q437'),
#    'triple_label': ('Slovenia', 'capital', 'Ljubljana')},
#   {'triple': ('Q437', 'P6', 'Q220521'),
#    'triple_label': ('Ljubljana', 'head of government', 'Zoran Janković')},
#   {'triple': ('Q220521', 'P69', 'Q1377'),
#    'triple_label': ('Zoran Janković',
#     'educated at',
#     'University of Ljubljana')},
#   {'triple': ('Q1377', 'P159', 'Q12794274'),
#    'triple_label': ('University of Ljubljana',
#     'headquarters location',
#     'University of Ljubljana Palace')}],
#  [{'triple': ('Q5772444', 'P40', 'Q5772448'),
#    'triple_label': ('Clemente Lococo', 'child', 'Clemente Lococo')},
#   {'triple': ('Q5772448', 'P27', 'Q414'),
#    'triple_label': ('Clemente Lococo', 'country of citizenship', 'Argentina')},
#   {'triple': ('Q414', 'P36', 'Q1486'),
#    'triple_label': ('Argentina', 'capital', 'Buenos Aires')},
#   {'triple': ('Q1486', 'P6', 'Q5935527'),
#    'triple_label': ('Buenos Aires', 'head of government', 'Jorge Macri')},
#   {'triple': ('Q5935527', 'P1412', 'Q1321'),
#    'triple_label': ('Jorge Macri',
#     'languages spoken, written or signed',
#     'Spanish')}],
#  [{'triple': ('Q119553393', 'P106', 'Q3665646'),
#    'triple_label': ('Kelli Inman', 'occupation', 'basketball player')},
#   {'triple': ('Q3665646', 'P641', 'Q5372'),
#    'triple_label': ('basketball player', 'sport', 'basketball')},
#   {'triple': ('Q5372', 'P495', 'Q30'),
#    'triple_label': ('basketball', 'country of origin', 'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q4259030', 'P20', 'Q649'),
#    'triple_label': ('Nikolay Leontyev', 'place of death', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')},
#   {'triple': ('Q1899', 'P6', 'Q31919'),
#    'triple_label': ('Kyiv', 'head of government', 'Vitali Klitschko')},
#   {'triple': ('Q31919', 'P19', 'Q816163'),
#    'triple_label': ('Vitali Klitschko', 'place of birth', 'Belovodskoye')}],
#  [{'triple': ('Q102180049', 'P69', 'Q492318'),
#    'triple_label': ('Chinku Chu', 'educated at', 'University of Alabama')},
#   {'triple': ('Q492318', 'P159', 'Q79580'),
#    'triple_label': ('University of Alabama',
#     'headquarters location',
#     'Tuscaloosa')},
#   {'triple': ('Q79580', 'P6', 'Q16214067'),
#    'triple_label': ('Tuscaloosa', 'head of government', 'Walter Maddox')},
#   {'triple': ('Q16214067', 'P27', 'Q30'),
#    'triple_label': ('Walter Maddox',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q12023870', 'P106', 'Q937857'),
#    'triple_label': ('Jaroslav Kotek',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q6399961', 'P106', 'Q937857'),
#    'triple_label': ('Khamis Eid Rafe Thani',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q64744876', 'P140', 'Q9592'),
#    'triple_label': ('Angelo Luigi Gioviio',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q65548520', 'P106', 'Q937857'),
#    'triple_label': ('Kuvondik Ruziev',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q106979033', 'P170', 'Q3319624'),
#    'triple_label': ('London Blackout', 'creator', 'Molly Bobak')},
#   {'triple': ('Q3319624', 'P69', 'Q1337587'),
#    'triple_label': ('Molly Bobak',
#     'educated at',
#     'Emily Carr University of Art and Design')},
#   {'triple': ('Q1337587', 'P159', 'Q24639'),
#    'triple_label': ('Emily Carr University of Art and Design',
#     'headquarters location',
#     'Vancouver')},
#   {'triple': ('Q24639', 'P112', 'Q472946'),
#    'triple_label': ('Vancouver', 'founded by', 'William Cornelius Van Horne')},
#   {'triple': ('Q472946', 'P20', 'Q3145206'),
#    'triple_label': ('William Cornelius Van Horne',
#     'place of death',
#     'Royal Victoria Hospital, Montreal')}],
#  [{'triple': ('Q97678049', 'P106', 'Q937857'),
#    'triple_label': ('Michelle Pistoia',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q117447815', 'P27', 'Q159856'),
#    'triple_label': ('Jan IV Hinckaert',
#     'country of citizenship',
#     'Duchy of Brabant')},
#   {'triple': ('Q159856', 'P36', 'Q2449703'),
#    'triple_label': ('Duchy of Brabant', 'capital', 'Coop of Brussels')},
#   {'triple': ('Q2449703', 'P112', 'Q703470'),
#    'triple_label': ('Coop of Brussels', 'founded by', 'John II')},
#   {'triple': ('Q703470', 'P26', 'Q2667593'),
#    'triple_label': ('John II', 'spouse', 'Margaret of England')},
#   {'triple': ('Q2667593', 'P40', 'Q541658'),
#    'triple_label': ('Margaret of England', 'child', 'John III')}],
#  [{'triple': ('Q17057512', 'P159', 'Q649'),
#    'triple_label': ('United Instrument Manufacturing Corporation',
#     'headquarters location',
#     'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')},
#   {'triple': ('Q1899', 'P6', 'Q31919'),
#    'triple_label': ('Kyiv', 'head of government', 'Vitali Klitschko')},
#   {'triple': ('Q31919', 'P19', 'Q816163'),
#    'triple_label': ('Vitali Klitschko', 'place of birth', 'Belovodskoye')}],
#  [{'triple': ('Q22125678', 'P108', 'Q10854520'),
#    'triple_label': ('Takashi Inoue', 'employer', 'FM Sendai')},
#   {'triple': ('Q10854520', 'P159', 'Q47896'),
#    'triple_label': ('FM Sendai',
#     'headquarters location',
#     'Miyagi Prefecture')},
#   {'triple': ('Q47896', 'P36', 'Q46747'),
#    'triple_label': ('Miyagi Prefecture', 'capital', 'Sendai')},
#   {'triple': ('Q46747', 'P6', 'Q6381535'),
#    'triple_label': ('Sendai', 'head of government', 'Kazuko Kōri')},
#   {'triple': ('Q6381535', 'P1412', 'Q5287'),
#    'triple_label': ('Kazuko Kōri',
#     'languages spoken, written or signed',
#     'Japanese')}],
#  [{'triple': ('Q113426144', 'P106', 'Q967769'),
#    'triple_label': ('Derry Sulaiman', 'occupation', "da'i")},
#   {'triple': ('Q967769', 'P140', 'Q432'),
#    'triple_label': ("da'i", 'religion or worldview', 'Islam')},
#   {'triple': ('Q432', 'P112', 'Q9458'),
#    'triple_label': ('Islam', 'founded by', 'Muhammad')},
#   {'triple': ('Q9458', 'P19', 'Q5806'),
#    'triple_label': ('Muhammad', 'place of birth', 'Mecca')},
#   {'triple': ('Q5806', 'P6', 'Q371263'),
#    'triple_label': ('Mecca', 'head of government', 'Khalid bin Faisal')}],
#  [{'triple': ('Q33953196', 'P50', 'Q56014747'),
#    'triple_label': ('IFN-alpha and IFN-beta: a link between immune memory and chronic inflammation.',
#     'author',
#     'Janet M Lord')},
#   {'triple': ('Q56014747', 'P69', 'Q750066'),
#    'triple_label': ('Janet M Lord', 'educated at', 'Aston University')},
#   {'triple': ('Q750066', 'P159', 'Q2256'),
#    'triple_label': ('Aston University',
#     'headquarters location',
#     'Birmingham')},
#   {'triple': ('Q2256', 'P6', 'Q55069059'),
#    'triple_label': ('Birmingham', 'head of government', 'Yvonne Mosquito')},
#   {'triple': ('Q55069059', 'P19', 'Q4852528'),
#    'triple_label': ('Yvonne Mosquito', 'place of birth', 'Balsall Heath')}],
#  [{'triple': ('Q14705108', 'P140', 'Q9592'),
#    'triple_label': ('Roman Martyrology',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q64736500', 'P140', 'Q9592'),
#    'triple_label': ('Francisco José Marán',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q110409896', 'P40', 'Q110409893'),
#    'triple_label': ('Sophia Winckler von Dölitz',
#     'child',
#     'Carl Abraham von Fritsch')},
#   {'triple': ('Q110409893', 'P40', 'Q110409892'),
#    'triple_label': ('Carl Abraham von Fritsch',
#     'child',
#     'Charlotte von Fritsch')},
#   {'triple': ('Q110409892', 'P40', 'Q110409878'),
#    'triple_label': ('Charlotte von Fritsch', 'child', 'Karl von Hugo')},
#   {'triple': ('Q110409878', 'P40', 'Q110409876'),
#    'triple_label': ('Karl von Hugo', 'child', 'Konstanze von Hugo')},
#   {'triple': ('Q110409876', 'P40', 'Q110409851'),
#    'triple_label': ('Konstanze von Hugo', 'child', 'Ottilie von Schell')}],
#  [{'triple': ('Q370181', 'P19', 'Q18419'),
#    'triple_label': ('William Daniels', 'place of birth', 'Brooklyn')},
#   {'triple': ('Q18419', 'P6', 'Q16204264'),
#    'triple_label': ('Brooklyn', 'head of government', 'Antonio Reynoso')},
#   {'triple': ('Q16204264', 'P27', 'Q30'),
#    'triple_label': ('Antonio Reynoso',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q3752032', 'P106', 'Q937857'),
#    'triple_label': ('Franklin Cale',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q7596004', 'P106', 'Q19204627'),
#    'triple_label': ('Stacy Andrews',
#     'occupation',
#     'American football player')},
#   {'triple': ('Q19204627', 'P641', 'Q41323'),
#    'triple_label': ('American football player', 'sport', 'American football')},
#   {'triple': ('Q41323', 'P495', 'Q30'),
#    'triple_label': ('American football',
#     'country of origin',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q57585693', 'P69', 'Q283032'),
#    'triple_label': ('Vaseem Iqbal', 'educated at', 'Pondicherry University')},
#   {'triple': ('Q283032', 'P488', 'Q370773'),
#    'triple_label': ('Pondicherry University',
#     'chairperson',
#     'Mohammad Hamid Ansari')},
#   {'triple': ('Q370773', 'P19', 'Q1348'),
#    'triple_label': ('Mohammad Hamid Ansari', 'place of birth', 'Kolkata')},
#   {'triple': ('Q1348', 'P6', 'Q4935088'),
#    'triple_label': ('Kolkata', 'head of government', 'Firhad Hakim')},
#   {'triple': ('Q4935088', 'P27', 'Q668'),
#    'triple_label': ('Firhad Hakim', 'country of citizenship', 'India')}],
#  [{'triple': ('Q75428908', 'P26', 'Q7965065'),
#    'triple_label': ('Isabel Elizabeth Lear', 'spouse', 'Walter Hamilton')},
#   {'triple': ('Q7965065', 'P39', 'Q1636762'),
#    'triple_label': ('Walter Hamilton',
#     'position held',
#     'Bishop of Salisbury')},
#   {'triple': ('Q1636762', 'P112', 'Q709718'),
#    'triple_label': ('Bishop of Salisbury', 'founded by', 'Aldhelm')},
#   {'triple': ('Q709718', 'P27', 'Q105313'),
#    'triple_label': ('Aldhelm', 'country of citizenship', 'Kingdom of Wessex')},
#   {'triple': ('Q105313', 'P36', 'Q172157'),
#    'triple_label': ('Kingdom of Wessex', 'capital', 'Winchester')}],
#  [{'triple': ('Q59556894', 'P50', 'Q5436128'),
#    'triple_label': ('Concurrent Processes', 'author', 'Faron Moller')},
#   {'triple': ('Q5436128', 'P69', 'Q160302'),
#    'triple_label': ('Faron Moller', 'educated at', 'University of Edinburgh')},
#   {'triple': ('Q160302', 'P159', 'Q23436'),
#    'triple_label': ('University of Edinburgh',
#     'headquarters location',
#     'Edinburgh')},
#   {'triple': ('Q23436', 'P6', 'Q31832763'),
#    'triple_label': ('Edinburgh', 'head of government', 'Frank Ross')},
#   {'triple': ('Q31832763', 'P19', 'Q84'),
#    'triple_label': ('Frank Ross', 'place of birth', 'London')}],
#  [{'triple': ('Q92941085', 'P50', 'Q58224014'),
#    'triple_label': ('Sensitivity analysis of muscle properties and impact parameters on head injury risk in American football',
#     'author',
#     'Andrew Merryweather')},
#   {'triple': ('Q58224014', 'P108', 'Q168515'),
#    'triple_label': ('Andrew Merryweather', 'employer', 'University of Utah')},
#   {'triple': ('Q168515', 'P112', 'Q203559'),
#    'triple_label': ('University of Utah', 'founded by', 'Brigham Young')},
#   {'triple': ('Q203559', 'P27', 'Q30'),
#    'triple_label': ('Brigham Young',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q21665562', 'P106', 'Q937857'),
#    'triple_label': ('Sidy Sarr', 'occupation', 'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q68909767', 'P140', 'Q9592'),
#    'triple_label': ('Alvaro Fernando de Parade',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q97747031', 'P106', 'Q937857'),
#    'triple_label': ('Michella Østergaard',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q5274576', 'P106', 'Q937857'),
#    'triple_label': ('Diego Benito Rey',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q38025969', 'P106', 'Q937857'),
#    'triple_label': ('Gerardo Corvalán',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q60165268', 'P50', 'Q59592002'),
#    'triple_label': ('Origin of the amplified spontaneous emission from thiophene/phenylene co-oligomer single crystals: Towards co-oligomer lasers',
#     'author',
#     'Fumio Sasaki')},
#   {'triple': ('Q59592002', 'P108', 'Q1076542'),
#    'triple_label': ('Fumio Sasaki',
#     'employer',
#     'National Institute of Advanced Industrial Science and Technology')},
#   {'triple': ('Q1076542', 'P488', 'Q1002290'),
#    'triple_label': ('National Institute of Advanced Industrial Science and Technology',
#     'chairperson',
#     'Ryōji Chūbachi')},
#   {'triple': ('Q1002290', 'P19', 'Q47896'),
#    'triple_label': ('Ryōji Chūbachi', 'place of birth', 'Miyagi Prefecture')},
#   {'triple': ('Q47896', 'P36', 'Q46747'),
#    'triple_label': ('Miyagi Prefecture', 'capital', 'Sendai')}],
#  [{'triple': ('Q859003', 'P176', 'Q1592306'),
#    'triple_label': ('East Japan Passenger Railway 253 series train.',
#     'manufacturer',
#     'Kinki Sharyo')},
#   {'triple': ('Q1592306', 'P159', 'Q243863'),
#    'triple_label': ('Kinki Sharyo', 'headquarters location', 'Higashiosaka')},
#   {'triple': ('Q243863', 'P6', 'Q11646043'),
#    'triple_label': ('Higashiosaka', 'head of government', 'Yoshikazu Noda')},
#   {'triple': ('Q11646043', 'P19', 'Q34600'),
#    'triple_label': ('Yoshikazu Noda', 'place of birth', 'Kyoto')},
#   {'triple': ('Q34600', 'P36', 'Q1075455'),
#    'triple_label': ('Kyoto', 'capital', 'Nakagyō Ward')}],
#  [{'triple': ('Q5617724', 'P69', 'Q854280'),
#    'triple_label': ('John Davidsson',
#     'educated at',
#     'Royal Institute of Technology')},
#   {'triple': ('Q854280', 'P1037', 'Q4753936'),
#    'triple_label': ('Royal Institute of Technology',
#     'director / manager',
#     'Anders Söderholm')},
#   {'triple': ('Q4753936', 'P27', 'Q34'),
#    'triple_label': ('Anders Söderholm', 'country of citizenship', 'Sweden')},
#   {'triple': ('Q34', 'P36', 'Q1754'),
#    'triple_label': ('Sweden', 'capital', 'Stockholm')},
#   {'triple': ('Q1754', 'P37', 'Q9027'),
#    'triple_label': ('Stockholm', 'official language', 'Swedish')}],
#  [{'triple': ('Q20862156', 'P170', 'Q237959'),
#    'triple_label': ('Untitled', 'creator', 'Lee Krasner')},
#   {'triple': ('Q237959', 'P19', 'Q18419'),
#    'triple_label': ('Lee Krasner', 'place of birth', 'Brooklyn')},
#   {'triple': ('Q18419', 'P6', 'Q16204264'),
#    'triple_label': ('Brooklyn', 'head of government', 'Antonio Reynoso')},
#   {'triple': ('Q16204264', 'P27', 'Q30'),
#    'triple_label': ('Antonio Reynoso',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q75945528', 'P26', 'Q21166826'),
#    'triple_label': ('Lady Juliana Colyear', 'spouse', 'Henry Dawkins')},
#   {'triple': ('Q21166826', 'P69', 'Q4667847'),
#    'triple_label': ('Henry Dawkins', 'educated at', 'Abingdon School')},
#   {'triple': ('Q4667847', 'P140', 'Q5043'),
#    'triple_label': ('Abingdon School',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')}],
#  [{'triple': ('Q12154353', 'P27', 'Q34266'),
#    'triple_label': ('Karpo Trofimovič Solenik',
#     'country of citizenship',
#     'Russian Empire')},
#   {'triple': ('Q34266', 'P112', 'Q8479'),
#    'triple_label': ('Russian Empire', 'founded by', 'Peter the Great')},
#   {'triple': ('Q8479', 'P19', 'Q649'),
#    'triple_label': ('Peter the Great', 'place of birth', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')}],
#  [{'triple': ('Q33551742', 'P50', 'Q63346778'),
#    'triple_label': ('Size-dependent magnetic tuning of lateral photovoltaic effect in nonmagnetic Si-based Schottky junctions',
#     'author',
#     'Hui Wang')},
#   {'triple': ('Q63346778', 'P108', 'Q525169'),
#    'triple_label': ('Hui Wang', 'employer', 'Shanghai Jiao Tong University')},
#   {'triple': ('Q525169', 'P112', 'Q1135660'),
#    'triple_label': ('Shanghai Jiao Tong University',
#     'founded by',
#     'Sheng Xuanhuai')},
#   {'triple': ('Q1135660', 'P20', 'Q8686'),
#    'triple_label': ('Sheng Xuanhuai', 'place of death', 'Shanghai')},
#   {'triple': ('Q8686', 'P36', 'Q660185'),
#    'triple_label': ('Shanghai', 'capital', 'Huangpu District')}],
#  [{'triple': ('Q100987122', 'P69', 'Q603034'),
#    'triple_label': ('Dave Williams', 'educated at', 'Drexel University')},
#   {'triple': ('Q603034', 'P112', 'Q2404150'),
#    'triple_label': ('Drexel University',
#     'founded by',
#     'Anthony Joseph Drexel')},
#   {'triple': ('Q2404150', 'P19', 'Q1345'),
#    'triple_label': ('Anthony Joseph Drexel',
#     'place of birth',
#     'Philadelphia')},
#   {'triple': ('Q1345', 'P112', 'Q209152'),
#    'triple_label': ('Philadelphia', 'founded by', 'William Penn')},
#   {'triple': ('Q209152', 'P19', 'Q84'),
#    'triple_label': ('William Penn', 'place of birth', 'London')}],
#  [{'triple': ('Q116007830', 'P40', 'Q116007828'),
#    'triple_label': ('Antoinette de Cadris',
#     'child',
#     'Catherine de Malingris')},
#   {'triple': ('Q116007828', 'P40', 'Q116007820'),
#    'triple_label': ('Catherine de Malingris',
#     'child',
#     "Jacques d'Albert, Seigneur de Boussargues et de Sabran")},
#   {'triple': ('Q116007820', 'P40', 'Q116007819'),
#    'triple_label': ("Jacques d'Albert, Seigneur de Boussargues et de Sabran",
#     'child',
#     "Léon d'Albert, Seigneur de Luynes")},
#   {'triple': ('Q116007819', 'P40', 'Q22084148'),
#    'triple_label': ("Léon d'Albert, Seigneur de Luynes",
#     'child',
#     "Honoré d'Albert")},
#   {'triple': ('Q22084148', 'P106', 'Q2478141'),
#    'triple_label': ("Honoré d'Albert", 'occupation', 'aristocrat')}],
#  [{'triple': ('Q65553792', 'P27', 'Q229'),
#    'triple_label': ('Pródomos Prodrómou', 'country of citizenship', 'Cyprus')},
#   {'triple': ('Q229', 'P35', 'Q48905549'),
#    'triple_label': ('Cyprus', 'head of state', 'Nicos Christodoulides')},
#   {'triple': ('Q48905549', 'P19', 'Q588760'),
#    'triple_label': ('Nicos Christodoulides', 'place of birth', 'Geroskipou')},
#   {'triple': ('Q588760', 'P6', 'Q56062278'),
#    'triple_label': ('Geroskipou', 'head of government', 'Michalis Pavlides')},
#   {'triple': ('Q56062278', 'P106', 'Q131524'),
#    'triple_label': ('Michalis Pavlides', 'occupation', 'entrepreneur')}],
#  [{'triple': ('Q71281552', 'P50', 'Q16159779'),
#    'triple_label': ('A case of endocarditis with an unusual clinical course',
#     'author',
#     'Janusz Alwasiak')},
#   {'triple': ('Q16159779', 'P19', 'Q158589'),
#    'triple_label': ('Janusz Alwasiak', 'place of birth', 'Pabianice')},
#   {'triple': ('Q158589', 'P6', 'Q19275020'),
#    'triple_label': ('Pabianice', 'head of government', 'Grzegorz Mackiewicz')},
#   {'triple': ('Q19275020', 'P69', 'Q137503'),
#    'triple_label': ('Grzegorz Mackiewicz',
#     'educated at',
#     'University of Łódź')},
#   {'triple': ('Q137503', 'P159', 'Q580'),
#    'triple_label': ('University of Łódź', 'headquarters location', 'Łódź')}],
#  [{'triple': ('Q6557863', 'P69', 'Q2341039'),
#    'triple_label': ('Lisa Carlton', 'educated at', 'Stetson University')},
#   {'triple': ('Q2341039', 'P112', 'Q16031688'),
#    'triple_label': ('Stetson University',
#     'founded by',
#     'Henry Addison DeLand')},
#   {'triple': ('Q16031688', 'P27', 'Q30'),
#    'triple_label': ('Henry Addison DeLand',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q112604598', 'P50', 'Q7403873'),
#    'triple_label': ('Shrimp and coastal adaptation: on the politics of climate justice',
#     'author',
#     'Saleemul Huq')},
#   {'triple': ('Q7403873', 'P19', 'Q2347909'),
#    'triple_label': ('Saleemul Huq', 'place of birth', 'East Bengal')},
#   {'triple': ('Q2347909', 'P140', 'Q432'),
#    'triple_label': ('East Bengal', 'religion or worldview', 'Islam')},
#   {'triple': ('Q432', 'P112', 'Q9458'),
#    'triple_label': ('Islam', 'founded by', 'Muhammad')},
#   {'triple': ('Q9458', 'P19', 'Q5806'),
#    'triple_label': ('Muhammad', 'place of birth', 'Mecca')}],
#  [{'triple': ('Q2001199', 'P176', 'Q912979'),
#    'triple_label': ('Northrop X-21', 'manufacturer', 'Northrop')},
#   {'triple': ('Q912979', 'P112', 'Q1113567'),
#    'triple_label': ('Northrop', 'founded by', 'Jack Northrop')},
#   {'triple': ('Q1113567', 'P19', 'Q25395'),
#    'triple_label': ('Jack Northrop', 'place of birth', 'Newark')},
#   {'triple': ('Q25395', 'P6', 'Q7294641'),
#    'triple_label': ('Newark', 'head of government', 'Ras Baraka')},
#   {'triple': ('Q7294641', 'P27', 'Q30'),
#    'triple_label': ('Ras Baraka', 'country of citizenship', 'United States')}],
#  [{'triple': ('Q7461395', 'P106', 'Q937857'),
#    'triple_label': ('Shahab Karami',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q6116720', 'P106', 'Q937857'),
#    'triple_label': ('Jackie Wassall',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q17535004', 'P140', 'Q6423963'),
#    'triple_label': ('Church of St. Peter',
#     'religion or worldview',
#     'Anglicanism')},
#   {'triple': ('Q6423963', 'P140', 'Q5043'),
#    'triple_label': ('Anglicanism', 'religion or worldview', 'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q16712904', 'P106', 'Q937857'),
#    'triple_label': ('Aleksandr Fedorov',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q4211683', 'P19', 'Q649'),
#    'triple_label': ('Andrey Kamorin', 'place of birth', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')},
#   {'triple': ('Q1899', 'P6', 'Q31919'),
#    'triple_label': ('Kyiv', 'head of government', 'Vitali Klitschko')},
#   {'triple': ('Q31919', 'P19', 'Q816163'),
#    'triple_label': ('Vitali Klitschko', 'place of birth', 'Belovodskoye')}],
#  [{'triple': ('Q30611126', 'P140', 'Q432'),
#    'triple_label': ('Tayyar Rahmiye', 'religion or worldview', 'Islam')},
#   {'triple': ('Q432', 'P112', 'Q9458'),
#    'triple_label': ('Islam', 'founded by', 'Muhammad')},
#   {'triple': ('Q9458', 'P19', 'Q5806'),
#    'triple_label': ('Muhammad', 'place of birth', 'Mecca')},
#   {'triple': ('Q5806', 'P6', 'Q371263'),
#    'triple_label': ('Mecca', 'head of government', 'Khalid bin Faisal')},
#   {'triple': ('Q371263', 'P27', 'Q851'),
#    'triple_label': ('Khalid bin Faisal',
#     'country of citizenship',
#     'Saudi Arabia')}],
#  [{'triple': ('Q21070762', 'P19', 'Q1094998'),
#    'triple_label': ('Frank Hasenfratz', 'place of birth', 'Szár')},
#   {'triple': ('Q1094998', 'P6', 'Q105761385'),
#    'triple_label': ('Szár', 'head of government', 'Norbert Németh')},
#   {'triple': ('Q105761385', 'P27', 'Q28'),
#    'triple_label': ('Norbert Németh', 'country of citizenship', 'Hungary')},
#   {'triple': ('Q28', 'P36', 'Q1781'),
#    'triple_label': ('Hungary', 'capital', 'Budapest')},
#   {'triple': ('Q1781', 'P37', 'Q9067'),
#    'triple_label': ('Budapest', 'official language', 'Hungarian')}],
#  [{'triple': ('Q102444770', 'P69', 'Q458393'),
#    'triple_label': ('Andrew Jonathan Pocklington',
#     'educated at',
#     'Durham University')},
#   {'triple': ('Q458393', 'P488', 'Q953628'),
#    'triple_label': ('Durham University', 'chairperson', 'Thomas Allen')},
#   {'triple': ('Q953628', 'P27', 'Q21'),
#    'triple_label': ('Thomas Allen', 'country of citizenship', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q119537280', 'P69', 'Q7240768'),
#    'triple_label': ('Dennaye Hinds', 'educated at', 'Presbyterian College')},
#   {'triple': ('Q7240768', 'P140', 'Q1149100'),
#    'triple_label': ('Presbyterian College',
#     'religion or worldview',
#     'Presbyterian Church')},
#   {'triple': ('Q1149100', 'P159', 'Q43668'),
#    'triple_label': ('Presbyterian Church',
#     'headquarters location',
#     'Louisville')},
#   {'triple': ('Q43668', 'P112', 'Q918990'),
#    'triple_label': ('Louisville', 'founded by', 'George Rogers Clark')},
#   {'triple': ('Q918990', 'P19', 'Q123766'),
#    'triple_label': ('George Rogers Clark',
#     'place of birth',
#     'Charlottesville')}],
#  [{'triple': ('Q1341439', 'P112', 'Q365930'),
#    'triple_label': ('Order of Muhammad Ali',
#     'founded by',
#     'Hussein Kamel of Egypt')},
#   {'triple': ('Q365930', 'P19', 'Q85'),
#    'triple_label': ('Hussein Kamel of Egypt', 'place of birth', 'Cairo')},
#   {'triple': ('Q85', 'P6', 'Q12223105'),
#    'triple_label': ('Cairo', 'head of government', 'Abd El Azim Wazir')},
#   {'triple': ('Q12223105', 'P27', 'Q79'),
#    'triple_label': ('Abd El Azim Wazir', 'country of citizenship', 'Egypt')},
#   {'triple': ('Q79', 'P37', 'Q13955'),
#    'triple_label': ('Egypt', 'official language', 'Arabic')}],
#  [{'triple': ('Q97681681', 'P106', 'Q937857'),
#    'triple_label': ('Eyleen Rymek',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q45951310', 'P50', 'Q59379923'),
#    'triple_label': ('Long-term stability of epinephrine dispensed in unsealed syringes for the first-aid treatment of anaphylaxis.',
#     'author',
#     'F. Estelle R. Simons')},
#   {'triple': ('Q59379923', 'P108', 'Q1191833'),
#    'triple_label': ('F. Estelle R. Simons',
#     'employer',
#     'University of Manitoba')},
#   {'triple': ('Q1191833', 'P159', 'Q2135'),
#    'triple_label': ('University of Manitoba',
#     'headquarters location',
#     'Winnipeg')},
#   {'triple': ('Q2135', 'P6', 'Q18378925'),
#    'triple_label': ('Winnipeg', 'head of government', 'Brian Bowman')},
#   {'triple': ('Q18378925', 'P106', 'Q82955'),
#    'triple_label': ('Brian Bowman', 'occupation', 'politician')}],
#  [{'triple': ('Q34866995', 'P50', 'Q94543201'),
#    'triple_label': ('Examining the link between traumatic events and delinquency among juvenile delinquent girls: A longitudinal study',
#     'author',
#     'Krista M. Chronister')},
#   {'triple': ('Q94543201', 'P108', 'Q766145'),
#    'triple_label': ('Krista M. Chronister',
#     'employer',
#     'University of Oregon')},
#   {'triple': ('Q766145', 'P112', 'Q57595883'),
#    'triple_label': ('University of Oregon',
#     'founded by',
#     'Joshua Jones Walton')},
#   {'triple': ('Q57595883', 'P27', 'Q30'),
#    'triple_label': ('Joshua Jones Walton',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')}],
#  [{'triple': ('Q102408451', 'P69', 'Q209344'),
#    'triple_label': ('Giuseppe Sindoni',
#     'educated at',
#     'Sapienza University of Rome')},
#   {'triple': ('Q209344', 'P112', 'Q134646'),
#    'triple_label': ('Sapienza University of Rome',
#     'founded by',
#     'Boniface VIII')},
#   {'triple': ('Q134646', 'P140', 'Q9592'),
#    'triple_label': ('Boniface VIII',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')}],
#  [{'triple': ('Q17535132', 'P140', 'Q6423963'),
#    'triple_label': ('Church of St Peter',
#     'religion or worldview',
#     'Anglicanism')},
#   {'triple': ('Q6423963', 'P140', 'Q5043'),
#    'triple_label': ('Anglicanism', 'religion or worldview', 'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q17527287', 'P140', 'Q6423963'),
#    'triple_label': ('Church of St Margaret',
#     'religion or worldview',
#     'Anglicanism')},
#   {'triple': ('Q6423963', 'P140', 'Q5043'),
#    'triple_label': ('Anglicanism', 'religion or worldview', 'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}],
#  [{'triple': ('Q96811594', 'P40', 'Q96811580'),
#    'triple_label': ('Elizabeth', 'child', 'John Wentworth')},
#   {'triple': ('Q96811580', 'P40', 'Q96811446'),
#    'triple_label': ('John Wentworth', 'child', 'Thomas Wentworth')},
#   {'triple': ('Q96811446', 'P40', 'Q96811438'),
#    'triple_label': ('Thomas Wentworth',
#     'child',
#     'Lieutenant Nataniel Wentworth')},
#   {'triple': ('Q96811438', 'P40', 'Q96811433'),
#    'triple_label': ('Lieutenant Nataniel Wentworth',
#     'child',
#     'Mose Wentworth')},
#   {'triple': ('Q96811433', 'P40', 'Q96811428'),
#    'triple_label': ('Mose Wentworth', 'child', 'Priscilla Wentworth')}],
#  [{'triple': ('Q12209951', 'P140', 'Q432'),
#    'triple_label': ('Khalid Al Ghamdi', 'religion or worldview', 'Islam')},
#   {'triple': ('Q432', 'P112', 'Q9458'),
#    'triple_label': ('Islam', 'founded by', 'Muhammad')},
#   {'triple': ('Q9458', 'P19', 'Q5806'),
#    'triple_label': ('Muhammad', 'place of birth', 'Mecca')},
#   {'triple': ('Q5806', 'P6', 'Q371263'),
#    'triple_label': ('Mecca', 'head of government', 'Khalid bin Faisal')},
#   {'triple': ('Q371263', 'P27', 'Q851'),
#    'triple_label': ('Khalid bin Faisal',
#     'country of citizenship',
#     'Saudi Arabia')}],
#  [{'triple': ('Q7795181', 'P69', 'Q458393'),
#    'triple_label': ('Thomas Williams', 'educated at', 'Durham University')},
#   {'triple': ('Q458393', 'P488', 'Q953628'),
#    'triple_label': ('Durham University', 'chairperson', 'Thomas Allen')},
#   {'triple': ('Q953628', 'P27', 'Q21'),
#    'triple_label': ('Thomas Allen', 'country of citizenship', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q98921593', 'P106', 'Q13382519'),
#    'triple_label': ('Crystal Wang', 'occupation', 'table tennis player')},
#   {'triple': ('Q13382519', 'P641', 'Q3930'),
#    'triple_label': ('table tennis player', 'sport', 'table tennis')},
#   {'triple': ('Q3930', 'P495', 'Q21'),
#    'triple_label': ('table tennis', 'country of origin', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q39067775', 'P50', 'Q59262666'),
#    'triple_label': ('Twenty-four hour urinary nitrate excretion in 48 populations from 30 countries: an ECP-INTERSALT collaborative study',
#     'author',
#     'Paul Elliott')},
#   {'triple': ('Q59262666', 'P108', 'Q189022'),
#    'triple_label': ('Paul Elliott', 'employer', 'Imperial College London')},
#   {'triple': ('Q189022', 'P112', 'Q20875'),
#    'triple_label': ('Imperial College London', 'founded by', 'Edward VII')},
#   {'triple': ('Q20875', 'P26', 'Q152260'),
#    'triple_label': ('Edward VII', 'spouse', 'Alexandra of Denmark')},
#   {'triple': ('Q152260', 'P19', 'Q2504988'),
#    'triple_label': ('Alexandra of Denmark',
#     'place of birth',
#     'Yellow Palace')}],
#  [{'triple': ('Q110161275', 'P170', 'Q3160960'),
#    'triple_label': ('[One from] A Volume of Drawings and Prints',
#     'creator',
#     'James Bulwer')},
#   {'triple': ('Q3160960', 'P140', 'Q6423963'),
#    'triple_label': ('James Bulwer', 'religion or worldview', 'Anglicanism')},
#   {'triple': ('Q6423963', 'P140', 'Q5043'),
#    'triple_label': ('Anglicanism', 'religion or worldview', 'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')}],
#  [{'triple': ('Q96241668', 'P40', 'Q96241667'),
#    'triple_label': ('Jean Gillis', 'child', 'Elisabeth Gillis')},
#   {'triple': ('Q96241667', 'P40', 'Q96241661'),
#    'triple_label': ('Elisabeth Gillis',
#     'child',
#     'Catharina de Bisschop, van Boutershem')},
#   {'triple': ('Q96241661', 'P40', 'Q96241644'),
#    'triple_label': ('Catharina de Bisschop, van Boutershem',
#     'child',
#     'Barbara Arents called Spierinck')},
#   {'triple': ('Q96241644', 'P40', 'Q1682176'),
#    'triple_label': ('Barbara Arents called Spierinck', 'child', 'Jan Rubens')},
#   {'triple': ('Q1682176', 'P26', 'Q2355955'),
#    'triple_label': ('Jan Rubens', 'spouse', 'Maria Pypelinckx')}],
#  [{'triple': ('Q16740157', 'P106', 'Q12299841'),
#    'triple_label': ('Liz Signal', 'occupation', 'cricketer')},
#   {'triple': ('Q12299841', 'P641', 'Q5375'),
#    'triple_label': ('cricketer', 'sport', 'cricket')},
#   {'triple': ('Q5375', 'P495', 'Q21'),
#    'triple_label': ('cricket', 'country of origin', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q20990947', 'P106', 'Q937857'),
#    'triple_label': ('Franco López',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q98201355', 'P50', 'Q86080335'),
#    'triple_label': ('Study on the Adsorption of CuFe2O4-Loaded Corncob Biochar for Pb(II)',
#     'author',
#     'Zichuan Ma')},
#   {'triple': ('Q86080335', 'P108', 'Q11141318'),
#    'triple_label': ('Zichuan Ma', 'employer', 'Hebei Normal University')},
#   {'triple': ('Q11141318', 'P159', 'Q58401'),
#    'triple_label': ('Hebei Normal University',
#     'headquarters location',
#     'Shijiazhuang')},
#   {'triple': ('Q58401', 'P36', 'Q1061855'),
#    'triple_label': ('Shijiazhuang', 'capital', "Chang'an District")},
#   {'triple': ('Q1061855', 'P36', 'Q8060147'),
#    'triple_label': ("Chang'an District", 'capital', 'Yucai Subdistrict')}],
#  [{'triple': ('Q21622979', 'P106', 'Q12299841'),
#    'triple_label': ('Bodavarapu Sudhakar', 'occupation', 'cricketer')},
#   {'triple': ('Q12299841', 'P641', 'Q5375'),
#    'triple_label': ('cricketer', 'sport', 'cricket')},
#   {'triple': ('Q5375', 'P495', 'Q21'),
#    'triple_label': ('cricket', 'country of origin', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q97693561', 'P106', 'Q937857'),
#    'triple_label': ('Myriam Baaziz',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q60708004', 'P50', 'Q50689682'),
#    'triple_label': ('On Possible Determination of the Speed of the Gravity Signal in Space with help of Gradiometry',
#     'author',
#     'Roberto Peron')},
#   {'triple': ('Q50689682', 'P108', 'Q542656'),
#    'triple_label': ('Roberto Peron',
#     'employer',
#     'National Institute for Astrophysics')},
#   {'triple': ('Q542656', 'P488', 'Q60286855'),
#    'triple_label': ('National Institute for Astrophysics',
#     'chairperson',
#     'Nicolò D’Amico')},
#   {'triple': ('Q60286855', 'P27', 'Q38'),
#    'triple_label': ('Nicolò D’Amico', 'country of citizenship', 'Italy')},
#   {'triple': ('Q38', 'P37', 'Q652'),
#    'triple_label': ('Italy', 'official language', 'Italian')}],
#  [{'triple': ('Q83371755', 'P50', 'Q60557379'),
#    'triple_label': ('On the role of surface charges for homogeneous freezing of supercooled water microdroplets',
#     'author',
#     'Alexei Kiselev')},
#   {'triple': ('Q60557379', 'P69', 'Q27621'),
#    'triple_label': ('Alexei Kiselev',
#     'educated at',
#     'Saint Petersburg State University')},
#   {'triple': ('Q27621', 'P112', 'Q8479'),
#    'triple_label': ('Saint Petersburg State University',
#     'founded by',
#     'Peter the Great')},
#   {'triple': ('Q8479', 'P19', 'Q649'),
#    'triple_label': ('Peter the Great', 'place of birth', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')}],
#  [{'triple': ('Q4910919', 'P106', 'Q12299841'),
#    'triple_label': ('Bill Smith', 'occupation', 'cricketer')},
#   {'triple': ('Q12299841', 'P641', 'Q5375'),
#    'triple_label': ('cricketer', 'sport', 'cricket')},
#   {'triple': ('Q5375', 'P495', 'Q21'),
#    'triple_label': ('cricket', 'country of origin', 'England')},
#   {'triple': ('Q21', 'P36', 'Q84'),
#    'triple_label': ('England', 'capital', 'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q5566331', 'P106', 'Q937857'),
#    'triple_label': ('Modou Barrow',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q102949245', 'P69', 'Q131252'),
#    'triple_label': ('Santiago Caicedo Soler',
#     'educated at',
#     'University of Chicago')},
#   {'triple': ('Q131252', 'P488', 'Q4162666'),
#    'triple_label': ('University of Chicago', 'chairperson', 'Robert Zimmer')},
#   {'triple': ('Q4162666', 'P27', 'Q30'),
#    'triple_label': ('Robert Zimmer',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q93360905', 'P159', 'Q649'),
#    'triple_label': ('MFB', 'headquarters location', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')},
#   {'triple': ('Q1899', 'P6', 'Q31919'),
#    'triple_label': ('Kyiv', 'head of government', 'Vitali Klitschko')},
#   {'triple': ('Q31919', 'P19', 'Q816163'),
#    'triple_label': ('Vitali Klitschko', 'place of birth', 'Belovodskoye')}],
#  [{'triple': ('Q30958702', 'P27', 'Q15180'),
#    'triple_label': ('Iakiv Galitch',
#     'country of citizenship',
#     'Soviet Union')},
#   {'triple': ('Q15180', 'P36', 'Q649'),
#    'triple_label': ('Soviet Union', 'capital', 'Moscow')},
#   {'triple': ('Q649', 'P112', 'Q275106'),
#    'triple_label': ('Moscow', 'founded by', 'Yuri Dolgorukiy')},
#   {'triple': ('Q275106', 'P20', 'Q1899'),
#    'triple_label': ('Yuri Dolgorukiy', 'place of death', 'Kyiv')},
#   {'triple': ('Q1899', 'P6', 'Q31919'),
#    'triple_label': ('Kyiv', 'head of government', 'Vitali Klitschko')}],
#  [{'triple': ('Q5037096', 'P159', 'Q18419'),
#    'triple_label': ('Captured Tracks', 'headquarters location', 'Brooklyn')},
#   {'triple': ('Q18419', 'P6', 'Q16204264'),
#    'triple_label': ('Brooklyn', 'head of government', 'Antonio Reynoso')},
#   {'triple': ('Q16204264', 'P27', 'Q30'),
#    'triple_label': ('Antonio Reynoso',
#     'country of citizenship',
#     'United States')},
#   {'triple': ('Q30', 'P35', 'Q22686'),
#    'triple_label': ('United States', 'head of state', 'Donald Trump')},
#   {'triple': ('Q22686', 'P1412', 'Q1860'),
#    'triple_label': ('Donald Trump',
#     'languages spoken, written or signed',
#     'English')}],
#  [{'triple': ('Q7671974', 'P159', 'Q1297'),
#    'triple_label': ('TTX Company', 'headquarters location', 'Chicago')},
#   {'triple': ('Q1297', 'P112', 'Q492555'),
#    'triple_label': ('Chicago', 'founded by', 'Jean Baptiste Point du Sable')},
#   {'triple': ('Q492555', 'P20', 'Q773432'),
#    'triple_label': ('Jean Baptiste Point du Sable',
#     'place of death',
#     'St. Charles')},
#   {'triple': ('Q773432', 'P6', 'Q75863187'),
#    'triple_label': ('St. Charles', 'head of government', 'Dan Borgmeyer')},
#   {'triple': ('Q75863187', 'P39', 'Q110713328'),
#    'triple_label': ('Dan Borgmeyer',
#     'position held',
#     'Mayor of St. Charles, Missouri')}],
#  [{'triple': ('Q7208100', 'P641', 'Q5377'),
#    'triple_label': ("Point O'Woods Golf & Country Club", 'sport', 'golf')},
#   {'triple': ('Q5377', 'P495', 'Q22'),
#    'triple_label': ('golf', 'country of origin', 'Scotland')},
#   {'triple': ('Q22', 'P36', 'Q23436'),
#    'triple_label': ('Scotland', 'capital', 'Edinburgh')},
#   {'triple': ('Q23436', 'P6', 'Q31832763'),
#    'triple_label': ('Edinburgh', 'head of government', 'Frank Ross')},
#   {'triple': ('Q31832763', 'P19', 'Q84'),
#    'triple_label': ('Frank Ross', 'place of birth', 'London')}],
#  [{'triple': ('Q21474183', 'P106', 'Q937857'),
#    'triple_label': ('Behrouz Afshar',
#     'occupation',
#     'association football player')},
#   {'triple': ('Q937857', 'P641', 'Q2736'),
#    'triple_label': ('association football player',
#     'sport',
#     'association football')},
#   {'triple': ('Q2736', 'P495', 'Q174193'),
#    'triple_label': ('association football',
#     'country of origin',
#     'United Kingdom of Great Britain and Ireland')},
#   {'triple': ('Q174193', 'P36', 'Q84'),
#    'triple_label': ('United Kingdom of Great Britain and Ireland',
#     'capital',
#     'London')},
#   {'triple': ('Q84', 'P37', 'Q1860'),
#    'triple_label': ('London', 'official language', 'English')}],
#  [{'triple': ('Q56276009', 'P641', 'Q5377'),
#    'triple_label': ('Horsforth Golf Club', 'sport', 'golf')},
#   {'triple': ('Q5377', 'P495', 'Q22'),
#    'triple_label': ('golf', 'country of origin', 'Scotland')},
#   {'triple': ('Q22', 'P36', 'Q23436'),
#    'triple_label': ('Scotland', 'capital', 'Edinburgh')},
#   {'triple': ('Q23436', 'P6', 'Q31832763'),
#    'triple_label': ('Edinburgh', 'head of government', 'Frank Ross')},
#   {'triple': ('Q31832763', 'P19', 'Q84'),
#    'triple_label': ('Frank Ross', 'place of birth', 'London')}],
#  [{'triple': ('Q100775627', 'P69', 'Q115376'),
#    'triple_label': ('Jeff Davis', 'educated at', 'West Virginia University')},
#   {'triple': ('Q115376', 'P159', 'Q653636'),
#    'triple_label': ('West Virginia University',
#     'headquarters location',
#     'Morgantown')},
#   {'triple': ('Q653636', 'P112', 'Q8064113'),
#    'triple_label': ('Morgantown', 'founded by', 'Zackquill Morgan')},
#   {'triple': ('Q8064113', 'P140', 'Q6423963'),
#    'triple_label': ('Zackquill Morgan',
#     'religion or worldview',
#     'Anglicanism')},
#   {'triple': ('Q6423963', 'P140', 'Q5043'),
#    'triple_label': ('Anglicanism', 'religion or worldview', 'Christianity')}],
#  [{'triple': ('Q110851415', 'P140', 'Q9592'),
#    'triple_label': ('Rozalia Zegarlińska',
#     'religion or worldview',
#     'Catholic Church')},
#   {'triple': ('Q9592', 'P140', 'Q5043'),
#    'triple_label': ('Catholic Church',
#     'religion or worldview',
#     'Christianity')},
#   {'triple': ('Q5043', 'P740', 'Q1218'),
#    'triple_label': ('Christianity', 'location of formation', 'Jerusalem')},
#   {'triple': ('Q1218', 'P6', 'Q12409594'),
#    'triple_label': ('Jerusalem', 'head of government', 'Moshe Leon')},
#   {'triple': ('Q12409594', 'P27', 'Q801'),
#    'triple_label': ('Moshe Leon', 'country of citizenship', 'Israel')}]]
